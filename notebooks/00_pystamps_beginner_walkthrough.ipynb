# %% [markdown]
# # 00. pySTAMPS beginner walkthrough
#
# This notebook is the gentle user-facing entry after `start_here.ipynb`. It is written for readers who do not already know interferometry, radar processing, or the StaMPS workflow.
#
# The goal is to help you understand what pySTAMPS does, what the main commands are, and which follow-up notebooks to open next without reading the whole repo first.

# %% [markdown]
# ## What pySTAMPS does
#
# `pystamps` is a Python implementation of a staged processing workflow for radar interferometry datasets.
#
# In plain language:
#
# - A **dataset** is a folder containing files that describe a radar scene and intermediate processing outputs.
# - A **stage** is one step in the workflow. pySTAMPS has stages 1 through 8.
# - A **persistent scatterer** is a ground point that stays stable enough across many images to be useful for measurement.
# - An **interferogram** is a comparison between two radar observations. It helps estimate how the phase changed.
# - **Verification** means comparing pySTAMPS outputs with a known STAMPS baseline dataset.
#
# You do not need to master the mathematics before using the tools safely. The first practical skills are learning how to inspect a dataset, preview what pySTAMPS would do, and verify outputs carefully.

# %% [markdown]
# ## Sample datasets used in these notebooks
#
# All notebooks in this set use the same repository dataset paths:
#
# - `inputs_and_outputs/InSAR_dataset_test`
# - `inputs_and_outputs/InSAR_dataset_test_stage8diag`
#
# If those datasets are missing in another checkout, the notebook cells tell you clearly instead of starting a heavy processing run.

# %%
from pathlib import Path

DATASET_MAIN = Path('inputs_and_outputs/InSAR_dataset_test')
DATASET_STAGE8 = Path('inputs_and_outputs/InSAR_dataset_test_stage8diag')

for path in (DATASET_MAIN, DATASET_STAGE8):
    print(f'{path}:', 'present' if path.exists() else 'missing')
# Out:
# inputs_and_outputs/InSAR_dataset_test: present
# inputs_and_outputs/InSAR_dataset_test_stage8diag: present

# %% [markdown]
# ## The notebook map
#
# Start with `start_here.ipynb` when you want the repo map, backend story, and tool inventory. This notebook is the lighter user path. The focused notebooks each explore one capability:
#
# 1. `01_pystamps_dataset_inspection.ipynb`: inspect folder layout and stage coverage.
# 2. `02_pystamps_stage_execution.ipynb`: understand stage ranges and safe dry-run-first execution.
# 3. `03_pystamps_verification.ipynb`: compare outputs with the STAMPS baseline dataset and interpret the result.
# 4. `04_rust_end2end_parity_validation.ipynb`: inspect native-backed parity evidence when you care about the Rust/backend contract.
#
# That sequence is intentional. A beginner should inspect first, then preview execution, then verify outputs.

# %% [markdown]
# ## The three commands you will use most often
#
# pySTAMPS can do many things, but most day-to-day exploration starts with these commands:
#
# - `pystamps status`: inspect dataset structure and inferred stage progress.
# - `pystamps run`: execute a stage range, usually on a copy of a dataset.
# - `pystamps verify`: compare one run folder against a trusted STAMPS baseline folder.

# %%
commands = [
    'uv run pystamps status --dataset inputs_and_outputs/InSAR_dataset_test',
    'uv run pystamps run --dataset inputs_and_outputs/InSAR_dataset_test --start-step 1 --end-step 8 --dry-run',
    'uv run pystamps verify --run inputs_and_outputs/InSAR_dataset_test --golden inputs_and_outputs/InSAR_dataset_test',
]

for command in commands:
    print(command)
# Out:
# uv run pystamps status --dataset inputs_and_outputs/InSAR_dataset_test
# uv run pystamps run --dataset inputs_and_outputs/InSAR_dataset_test --start-step 1 --end-step 8 --dry-run
# uv run pystamps verify --run inputs_and_outputs/InSAR_dataset_test --golden inputs_and_outputs/InSAR_dataset_test

# %% [markdown]
# ## A note about safety
#
# These notebooks do **not** automatically launch a full processing job.
#
# That is deliberate. Stage execution can take a long time, may write outputs into the dataset folder, and may depend on external tools such as `triangle` and `snaphu`.
#
# When you are still learning:
#
# - start with `status`
# - use `run --dry-run` before real execution
# - treat verification as a read-only comparison step

# %% [markdown]
# ## A note about `make verify`
#
# This repository also has a `make verify` helper, but it is **not** a generic replacement for `pystamps verify --run ... --golden ...`.
#
# Use the generic `pystamps verify` command when you want to compare arbitrary paths. The `make verify` target is only a convenience shortcut for this repository's fixed STAMPS-path case.

# %% [markdown]
# ## What to open next
#
# - Open `start_here.ipynb` if you want the repo map, CLI/tool inventory, and backend overview.
# - Open `01_pystamps_dataset_inspection.ipynb` if you want to understand how pySTAMPS reads a dataset folder.
# - Open `02_pystamps_stage_execution.ipynb` if you want to understand the stage-based execution model.
# - Open `03_pystamps_verification.ipynb` if you want to understand how to compare outputs with a trusted baseline.
# - Open `04_rust_end2end_parity_validation.ipynb` if you want the native-backed parity view.
